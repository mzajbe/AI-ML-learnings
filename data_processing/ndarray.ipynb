# %%
arr = [1,2,3]

print(arr * 5) #its multiply the whole array 5 times

arr = [x*5 for x in arr]

print(arr)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]
# [5, 10, 15]

# %%
# %pip install numpy
import numpy as np

arr1 = np.array(arr)  # using existing arr variable

arr1 = arr1 * 5

print(arr1)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 get_ipython().run_line_magic('pip', 'install numpy')
#       2 import numpy as np
# ----> 4 arr1 = np.array(arr)  # using existing arr variable
#       6 arr1 = arr1 * 5
#       8 print(arr1)
#
# NameError: name 'arr' is not defined
